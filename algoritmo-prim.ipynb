# %% [markdown]
# Algoritmo Prim

# %%
import networkx as nx
 
H= nx.Graph() 
H.add_edges_from([
                        (1,2), 
                        (1,3), 
                        (3,2), 
                        (1,6), 
                        (3,5),
                        (3,9),
                        (1,5),
                        (4,2),
                        (2,3),
                        (3,1),
                        (4,0)])
 
nx.draw(H, with_labels=True, font_weight='bold')
for i in range(4):
    (node1, node2)=list(H.edges)[i]
    H.add_edge(node1, node2)
    if nx.cycle_basis(H)!=[]:
        H.remove_edge(node1,node2)
b=list(H.edges(data='weight'))
min_weight=0
for i in range(len(b)):
    (src,dest,w)=b[i]
    min_weight=min_weight+int(1)
print("El árbol de expansión mínimo es ",min_weight)
# Out:
# El árbol de expansión mínimo es  5
