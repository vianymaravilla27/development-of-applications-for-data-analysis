# %% [markdown]
# Simpson

# %%
a = input("Introduce el valor del limite inferior")
b = input("Introduce el valor del limite superior")
n = input("Introduce el número de iteraciones a resolver") 

a = int(a)
b = int(b)
n = int(n)
# Out:
# Failed to start the Kernel.
#
# Failed to start the Kernel 'Python 3.9.8 64-bit'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Kernel has not been started

# %%
from math import *
#funcion auxiliar para ejecutar f(x)
def fx(x, f):
    return eval(f)

f = '(x)'
f2 = '(x)**2'

def simpson(n, a, b, f):
    h = (b - a) / n
    print(h)
    suma = 0.0
    for i in range(1, n):       
        x = a + i * h
        print("valor x",i, "= ",x)
        if(i % 2 == 0):
            #si es par lo vamos a multiplicar por 2
            suma = suma + 2 * fx(x, f)
            print("valor suma par",i,"=",suma)
        else:
            #si es impar lo vamos a multiplicar por 4
            suma = suma + 4 * fx(x, f)
            print("valor suma impar",i,"=",suma)
            
    suma = suma + fx(a, f) + fx(b, f)
    resultado = suma * (h / 3)
    return (resultado)
print(simpson(n, a, b, f))
# Out:
# 0.02
# valor x 1 =  0.02
# valor suma impar 1 = 0.08
# valor x 2 =  0.04
# valor suma par 2 = 0.16
# valor x 3 =  0.06
# valor suma impar 3 = 0.4
# valor x 4 =  0.08
# valor suma par 4 = 0.56
# valor x 5 =  0.1
# valor suma impar 5 = 0.9600000000000001
# valor x 6 =  0.12
# valor suma par 6 = 1.2000000000000002
# valor x 7 =  0.14
# valor suma impar 7 = 1.7600000000000002
# valor x 8 =  0.16
# valor suma par 8 = 2.08
# valor x 9 =  0.18
# valor suma impar 9 = 2.8
# valor x 10 =  0.2
# valor suma par 10 = 3.1999999999999997
# valor x 11 =  0.22
# valor suma impar 11 = 4.08
# valor x 12 =  0.24
# valor suma par 12 = 4.5600000000000005
# valor x 13 =  0.26
# valor suma impar 13 = 5.6000000000000005
# valor x 14 =  0.28
# valor suma par 14 = 6.16
# valor x 15 =  0.3
# valor suma impar 15 = 7.36
# valor x 16 =  0.32
# valor suma par 16 = 8.0
# valor x 17 =  0.34
# valor suma impar 17 = 9.36
# valor x 18 =  0.36
# valor suma par 18 = 10.08
# valor x 19 =  0.38
# valor suma impar 19 = 11.6
# ...
